# %%
from transformers import AutoTokenizer, AutoModel
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
import copy

# %%
all_party_textes_df = pd.read_parquet("all_parties_text_combined_prep_classified.parquet")
labled_theses_df = pd.read_parquet('wahlomat_thesen_prep.parquet')
Labled_theses_classification_df = pd.read_parquet('wahlomaten_thesen_positionen_classified.parquet')

labled_theses_df['Predicted_Class'] = Labled_theses_classification_df['Predicted_Class']
del Labled_theses_classification_df

# %%
all_party_textes_df
# Out:
#      Party                                            Chapter  \
# 3      spd  1. Wir kämpfen für neues Wachstum und sichere ...
# 4      spd  1. Wir kämpfen für neues Wachstum und sichere ...
# 5      spd  1. Wir kämpfen für neues Wachstum und sichere ...
# 6      spd  1. Wir kämpfen für neues Wachstum und sichere ...
# 8      spd            2. Wir kämpfen für Made in Germany 2.0.
# ..     ...                                                ...
# 618  linke  17. Für eine gerechte Einwanderungsgesellschaf...
# 619  linke  17. Für eine gerechte Einwanderungsgesellschaf...
# 622  linke  19. Medien und Kultur für eine plurale Gesells...
# 623  linke  19. Medien und Kultur für eine plurale Gesells...
# 624  linke  19. Medien und Kultur für eine plurale Gesells...
#
#                                                  These  \
# 3    Wir wollen Energiepreise senken und zentrale E...
# 4    Wir wollen, dass Unternehmen die besten Rahmen...
# 5    Wir wollen Bürokratie abbauen und Verfahren be...
# 6    Wir wollen Innovationen ermöglichen, die Deuts...
# 8    Wir wollen eine stabile, breit aufgestellte un...
# ..                                                 ...
# 618                          Niemand flieht freiwillig
# 619  Wir sind eine Einwanderungsgesellschaft – und ...
# 622        Kultur – vielfältig und für alle zugänglich
# 623                               Sport ist kein Luxus
# 624  Verbraucher*innen stärken. Schluss mit den Sch...
#
#                                                   Text  \
# 3    Wir brauchen bezahlbare Energie, sonst geht un...
# 4    Wir können etwas tun für unsere Unternehmen un...
# 5    Damit unsere Wirtschaft wieder schnell in Schw...
# 6    Der viel beschworene Erfndergeist in Deutschla...
# 8    Unsere Unternehmen müssen sicher sein, dass si...
# ..                                                 ...
# 618  Das Chaos an den europäischen Grenzen ist das ...
# 619  Die großen Herausforderungen von mehr Personal...
# 622  Der Zugang zu Kultur soll nicht vom Geldbeutel...
# 623  Sport ist für alle da. Dafür müssen die Zugang...
# 624  Die Konzerne nutzen ihre Macht gegenüber Verbr...
#
#                                      Text_no_stopwords  \
# 3    brauchen bezahlbare energie geht unternehmen d...
# 4    tun unternehmen wirtschaftsstandort schaffen d...
# 5    wirtschaft schnell schwung kommt müssen viele ...
# 6    beschworene erfndergeist deutschland obersten ...
# 8    unternehmen müssen sicher klimaneutralität wei...
# ..                                                 ...
# 618  chaos europäischen grenzen ergebnis politikver...
# 619  großen herausforderungen mehr personal gesundh...
# 622  zugang kultur geldbeutel abhängen kunst kultur...
# 623  sport dafür müssen zugangsbedingungen verbesse...
# 624  konzerne nutzen macht gegenüber verbraucher in...
#
#                                     These_no_stopwords  \
# 3    energiepreise senken zentrale erfolgsbranchen ...
# 4    unternehmen besten rahmenbedingungen deutschla...
# 5           bürokratie abbauen verfahren beschleunigen
# 6    innovationen ermöglichen deutschland voranbringen
# 8    stabile breit aufgestellte zukunftsfähige wirt...
# ..                                                 ...
# 618                          niemand flieht freiwillig
# 619                   einwanderungsgesellschaft müssen
# 622                       kultur vielfältig zugänglich
# 623                                        sport luxus
# 624   verbraucher innen stärken schluss schuldenfallen
#
#                                        Text_lemmatized  \
# 3    brauchen bezahlbar Energie gehen Unternehmen D...
# 4    tun Unternehmen Wirtschaftsstandort schaffen D...
# 5    Wirtschaft schnell Schwung kommen müssen viele...
# 6    beschworen Erfndergeist Deutschland oberer Pri...
# 8    Unternehmen müssen sicher Klimaneutralität wei...
# ..                                                 ...
# 618  Chaos europäisch Grenze Ergebnis Politikversag...
# 619  groß Herausforderung mehr Personal Gesundheit ...
# 622  Zugang Kultur Geldbeutel abhängen Kunst Kultur...
# 623  Sport dafür müssen Zugangsbedingung verbessern...
# 624  Konzern nutzen machen gegenüber Verbraucher in...
#
#                                       These_lemmatized  \
# 3    Energiepreise senken zentral erfolgsbranche st...
# 4    Unternehmen gut Rahmenbedingung Deutschland in...
# 5           Bürokratie abbauen Verfahren beschleunigen
# 6      Innovation ermöglichen Deutschland voranbringen
# 8    stabil breit aufgestellt zukunftsfähig Wirtschaft
# ..                                                 ...
# 618                         niemand fliehen freiwillig
# 619                   Einwanderungsgesellschaft müssen
# 622                       Kultur vielfältig zugänglich
# 623                                        Sport Luxus
# 624    Verbraucher innen stärken Schluss Schuldenfalle
#
#                                     These_unique_words  These_Word_Count  \
# 3    Energiepreise senken zentral erfolgsbranche st...                 9
# 4    Unternehmen gut Rahmenbedingung Deutschland in...                13
# 5           Bürokratie abbauen Verfahren beschleunigen                 7
# 6      Innovation ermöglichen Deutschland voranbringen                 7
# 8    stabil breit aufgestellt zukunftsfähig Wirtschaft                 9
# ..                                                 ...               ...
# 618                         niemand fliehen freiwillig                 3
# 619                   Einwanderungsgesellschaft müssen                10
# 622                       Kultur vielfältig zugänglich                 7
# 623                                        Sport Luxus                 4
# 624    Verbraucher innen stärken Schluss Schuldenfalle                 6
#
#      Text_Word_Count  Total_Word_Count  \
# 3                659               668
# 4                394               407
# 5                266               273
# 6                431               438
# 8                284               293
# ..               ...               ...
# 618              330               333
# 619              586               596
# 622              254               261
# 623              136               140
# 624              187               193
#
#                                       Predicted_Class
# 3                                    402 - Incentives
# 4                                    402 - Incentives
# 5    303 - Governmental and Administrative Efficiency
# 6                 411 - Technology and Infrastructure
# 8                                408 - Economic Goals
# ..                                                ...
# 618                    201 - Freedom and Human Rights
# 619                  607 - Multiculturalism: Positive
# 622                          503 - Equality: Positive
# 623                          503 - Equality: Positive
# 624                           403 - Market Regulation
#
# [564 rows x 13 columns]

# %%
labled_theses_df
# Out:
#                                                 These  \
# 0   Alle Beschäftigten sollen bereits nach 40 Beit...
# 1   Alle Bürgerinnen und Bürger sollen in gesetzli...
# 2   An Bahnhöfen soll die Bundespolizei Software z...
# 3   Asylsuchende sollen in Deutschland sofort nach...
# 4   Asylsuchende, die über einen anderen EU-Staat ...
# 5   Auf allen Autobahnen soll ein generelles Tempo...
# 6   Aus Deutschland sollen weiterhin Rüstungsgüter...
# 7   Bei Neuvermietungen sollen die Mietpreise weit...
# 8   Bei der Besteuerung von Einkommen soll der Spi...
# 9   Beim Ausbau der Verkehrsinfrastruktur soll die...
# 10  Das Bürgergeld soll denjenigen gestrichen werd...
# 11  Das Streikrecht für Beschäftigte in Unternehme...
# 12  Der Ausbau erneuerbarer Energien soll weiterhi...
# 13  Der Bund soll Projekte gegen Rechtsextremismus...
# 14  Der Bund soll mehr Kompetenzen in der Schulpol...
# 15  Der Euro soll in Deutschland durch eine nation...
# 16  Der gesetzliche Mindestlohn soll spätestens 20...
# 17  Deutschland soll das Ziel verwerfen, klimaneut...
# 18  Deutschland soll die Ukraine weiterhin militär...
# 19  Deutschland soll sich für die Abschaffung der ...
# 20  Deutschland soll weiterhin die Anwerbung von F...
# 21  Die Ausbildungsförderung BAföG soll weiterhin ...
# 22  Die Grundsteuer soll weiterhin auf Mieterinnen...
# 23  Die Schuldenbremse im Grundgesetz soll beibeha...
# 24  Die gesetzliche Frauenquote in Vorständen und ...
# 25  Ehrenamtliche Tätigkeiten sollen auf die zukün...
# 26  Energieintensive Unternehmen sollen vom Staat ...
# 27  Für die Stromerzeugung soll Deutschland wieder...
# 28  Für junge Erwachsene soll ein soziales Pflicht...
# 29  Im einleitenden Satz des Grundgesetzes soll we...
# 30  In Deutschland soll die 35-Stunden-Woche als g...
# 31  In Deutschland soll es auf Bundesebene Volksen...
# 32  In Deutschland soll es weiterhin generell mögl...
# 33  Neue Heizungen sollen auch zukünftig vollständ...
# 34  Schwangerschaftsabbrüche sollen in den ersten ...
# 35  Unter 14-Jährige sollen strafrechtlich belangt...
# 36  Unternehmen sollen weiterhin die Einhaltung de...
# 37  Ökologische Landwirtschaft soll stärker geförd...
#
#                                    These_no_stopwords  \
# 0   beschäftigten sollen bereits 40 beitragsjahren...
# 1   bürgerinnen bürger sollen gesetzlichen kranken...
# 2   bahnhöfen bundespolizei software automatisiert...
# 3   asylsuchende sollen deutschland sofort antrags...
# 4   asylsuchende eingereist sollen deutschen grenz...
# 5             autobahnen generelles tempolimit gelten
# 6   deutschland sollen weiterhin rüstungsgüter isr...
# 7   neuvermietungen sollen mietpreise weiterhin ge...
# 8   besteuerung einkommen spitzensteuersatz angehoben
# 9   beim ausbau verkehrsinfrastruktur schiene vorr...
# 10  bürgergeld denjenigen gestrichen wiederholt st...
# 11  streikrecht beschäftigte unternehmen kritische...
# 12  ausbau erneuerbarer energien weiterhin staat f...
# 13  bund projekte rechtsextremismus verstärkt fördern
# 14        bund mehr kompetenzen schulpolitik erhalten
# 15         euro deutschland nationale währung ersetzt
# 16  gesetzliche mindestlohn spätestens 2026 15 eur...
# 17            deutschland ziel verwerfen klimaneutral
# 18  deutschland ukraine weiterhin militärisch unte...
# 19  deutschland abschaffung erhöhten chinesische e...
# 20  deutschland weiterhin anwerbung fachkräften au...
# 21  ausbildungsförderung bafög weiterhin abhängig ...
# 22  grundsteuer weiterhin mieterinnen mieter umgel...
# 23             schuldenbremse grundgesetz beibehalten
# 24  gesetzliche frauenquote vorständen aufsichtsrä...
# 25  ehrenamtliche tätigkeiten sollen zukünftige re...
# 26  energieintensive unternehmen sollen staat fina...
# 27      stromerzeugung deutschland kernenergie nutzen
# 28   junge erwachsene soziales pflichtjahr eingeführt
# 29  einleitenden satz grundgesetzes weiterhin form...
# 30  deutschland gesetzliche regelarbeitszeit besch...
# 31      deutschland bundesebene volksentscheide geben
# 32  deutschland weiterhin generell möglich neben d...
stimme nicht zu  stimme nicht zu        stimme zu  stimme nicht zu
# 28  stimme nicht zu  stimme nicht zu          neutral  stimme nicht zu
# 29          neutral        stimme zu        stimme zu  stimme nicht zu
# 30  stimme nicht zu          neutral  stimme nicht zu        stimme zu
# 31  stimme nicht zu          neutral        stimme zu        stimme zu
# 32        stimme zu        stimme zu  stimme nicht zu        stimme zu
# 33  stimme nicht zu  stimme nicht zu        stimme zu  stimme nicht zu
# 34  stimme nicht zu  stimme nicht zu        stimme zu  stimme nicht zu
# 35  stimme nicht zu  stimme nicht zu        stimme zu  stimme nicht zu
# 36        stimme zu        stimme zu  stimme nicht zu        stimme zu
# 37        stimme zu        stimme zu  stimme nicht zu        stimme zu
#
#                 FDP                           Predicted_Class
# 0   stimme nicht zu             504 - Welfare State Expansion
# 1   stimme nicht zu             504 - Welfare State Expansion
# 2   stimme nicht zu             605 - Law and Order: Positive
# 3           neutral      602 - National Way of Life: Negative
# 4         stimme zu     705 - Underprivileged Minority Groups
# 5   stimme nicht zu       411 - Technology and Infrastructure
# 6         stimme zu          107 - Internationalism: Positive
# 7   stimme nicht zu                  412 - Controlled Economy
# 8   stimme nicht zu                  503 - Equality: Positive
# 9   stimme nicht zu       411 - Technology and Infrastructure
# 10        stimme zu            505 - Welfare State Limitation
# 11        stimme zu             701 - Labour Groups: Positive
# 12  stimme nicht zu  501 - Environmental Protection: Positive
# 13        stimme zu                           202 - Democracy
# 14        stimme zu                      302 - Centralisation
# 15  stimme nicht zu  110 - European Community/Union: Negative
# 16  stimme nicht zu                  412 - Controlled Economy
# 17  stimme nicht zu  501 - Environmental Protection: Positive
# 18        stimme zu                  104 - Military: Positive
# 19        stimme zu             407 - Protectionism: Negative
# 20        stimme zu       411 - Technology and Infrastructure
# 21  stimme nicht zu                  503 - Equality: Positive
# 22        stimme zu                   403 - Market Regulation
# 23        stimme zu                  414 - Economic Orthodoxy
# 24          neutral                  503 - Equality: Positive
# 25  stimme nicht zu          606 - Civic Mindedness: Positive
# 26  stimme nicht zu                          402 - Incentives
# 27        stimme zu  501 - Environmental Protection: Positive
# 28  stimme nicht zu          606 - Civic Mindedness: Positive
# 29          neutral         204 - Constitutionalism: Negative
# 30  stimme nicht zu             701 - Labour Groups: Positive
# 31  stimme nicht zu                           202 - Democracy
# 32        stimme zu          607 - Multiculturalism: Positive
# 33        stimme zu  501 - Environmental Protection: Positive
# 34          neutral      604 - Traditional Morality: Negative
# 35  stimme nicht zu             605 - Law and Order: Positive
# 36  stimme nicht zu            201 - Freedom and Human Rights
# 37  stimme nicht zu   703 - Agriculture and Farmers: Positive

# %%
lable_colums_list = labled_theses_df.columns[1:].tolist()

replace_dict = {
    'spd'   :   'SPD', 
    'cdu'   :   'CDU / CSU', 
    'gruene':   'GRÜNE', 
    'afd'   :   'AfD',
    'fdp'   :   'FDP', 
    'linke' :   'Die Linke'
}

all_party_textes_df['Party'] = all_party_textes_df['Party'].replace(replace_dict)
del replace_dict

# %%
# Load tokenizer and model
model_name = "mmmaurer/sbert-hashtag-german-politicians-2021"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)



def get_embedding(text:str, pooling_method:str = 'mean'):
    # Tokenize the input
    inputs = tokenizer(text, padding=True, truncation=True, return_tensors="pt")

    # Get model output (embeddings)
    outputs = model(**inputs)

    # Extract the embeddings from the model output
    match pooling_method:
        case 'mean':
            return outputs.last_hidden_state.mean(dim=1).squeeze().detach().numpy()
        case 'max':
            return outputs.last_hidden_state.max(dim=1).values.squeeze().detach().numpy()
        case _:
            raise ValueError(f'The used pooling method ({pooling_method}) is not supported. Use "mean" or "max".')

# %%
def similarity_func(all_party_textes_df: pd.DataFrame, 
                    labled_theses_df: pd.DataFrame, 
                    lable_text_column: str, 
                    party_text_column: str,
                    min_similarity_percentage:float = 0.6,
                    plot: bool = False, 
                    pooling_method: str = 'mean'):
    
    # Adjazenzmatrix einlesen
    matrix = pd.read_parquet('adjazenzmatrix.parquet')

    # Liste der Parteien und Thesen
    all_party_textes_df['Chapter'] = all_party_textes_df['Chapter'].fillna('-')
    parties_list = all_party_textes_df['Party'].unique().tolist()
    predicted_theses_df = copy.deepcopy(labled_theses_df)
    
    labled_text_list = labled_theses_df[lable_text_column].tolist()
    predicted_theses_dfs_dict = {}

    # Schleife über die Parteien
    for party_str in parties_list:
        # Filtern der Daten für die aktuelle Partei
        party_df = all_party_textes_df[all_party_textes_df['Party'] == party_str]

        # Entfernen von Zeilen mit NaN-Werten
        party_df = party_df.dropna()

        # Extrahieren der Thesen für die aktuelle Partei
        party_text_list = party_df[party_text_column].to_list()

        # Erstellung eines DataFrames zur Berechnung der Ähnlichkeiten
        similarity_df = pd.DataFrame(columns=['party_text'] + labled_text_list)

        # Berechnung der Ähnlichkeit für jede Partei-These
        for party_text in party_text_list:
            party_text_embedding = get_embedding(party_text, pooling_method=pooling_method)
            row = [party_text]

            # Verwende nur die ersten 3 Zeichen der Predicted_Class der Partei
            party_domain_num = party_df[party_df[party_text_column]==party_text]['Predicted_Class'].str[0:3].values[0]
            # Berechnung der Kosinusähnlichkeit für jede labelte These
            for label_text in labled_text_list:
                # Verwende nur die ersten 3 Zeichen der Predicted_Class der These
                label_domain_num = labled_theses_df[labled_theses_df[lable_text_column] == label_text]['Predicted_Class'].str[0:3].values[0]
                label_text_embedding = get_embedding(label_text, pooling_method=pooling_method)
                similarity_score = cosine_similarity(party_text_embedding.reshape(1, -1), label_text_embedding.reshape(1, -1))[0][0]

                # Wenn die Predicted_Class der Partei und der These übereinstimmt, verwenden wir die Kosinusähnlichkeit
                if matrix.loc[label_domain_num, party_domain_num] == 1:
                    similarity_score = similarity_score  if similarity_score > min_similarity_percentage else 0
                    
                # Wenn keine Übereinstimmung gefunden wird, suchen wir in der Adjazenzmatrix nach dem Gegenteil
                elif matrix.loc[label_domain_num, party_domain_num] == -1:
                    similarity_score = (-1*similarity_score) if similarity_score > min_similarity_percentage else 0

                else:
                    similarity_score = 0  # Keine Übereinstimmung und kein Gegenteil, setze Ähnlichkeit auf 0
                        
                row.append(similarity_score)

            similarity_df.loc[len(similarity_df)] = row

        if plot:
            # Visualisierung der Ähnlichkeiten als Heatmap
            plt.figure(figsize=(18, 18))
            sns.heatmap(similarity_df[labled_text_list],
                        cmap='RdYlGn',
                        annot=False,
                        vmax=1,
                        vmin=0,
                        yticklabels=party_df["These"])
            plt.xticks(rotation=45, ha="right")
            plt.title(f"Thesen-Heatmap: {party_str}")
            plt.show()

        # Maximale Ähnlichkeit für jede Partei
        predicted_theses_dfs_dict[party_str] = similarity_df
        max_index = similarity_df[labled_text_list].abs().idxmax()
        predicted_theses_df[party_str] = [similarity_df.loc[index, column] for column, index in max_index.items()]


    return predicted_theses_dfs_dict, predicted_theses_df

# %%
#lable_text_column = 'These_lemmatized'
#party_text_column = 'These_lemmatized'
#predicted_theses_dfs_dict, predicted_theses_df = similarity_func(all_party_textes_df,labled_theses_df,lable_text_column,party_text_column, plot=False)

# %%
#predicted_theses_df

# %%
lable_list = ["stimme nicht zu", "neutral", "stimme zu" ]

def mapping_similarity_to_class_func(predicted_theses_df:pd.DataFrame, lable_list:list):
    # Mapping-Funktion als Lambda-Ausdruck
    map_value = lambda val: (lable_list[0] if val < 0 else
                             lable_list[2] if val > 0 else
                             lable_list[1])
    
    # Kopie des DataFrames mit transformierten Werten
    predicted_theses_df_mapped = predicted_theses_df.copy()
    numeric_columns = predicted_theses_df.select_dtypes(include=['number']).columns
    predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
    
    # Anzeigen des gemappten DataFrames
    return predicted_theses_df_mapped

# %%
parties_list = ['CDU / CSU', 'GRÜNE', 'SPD', 'AfD', 'Die Linke', 'FDP']

def prediction_metric_func(predicted_theses_df_mapped:pd.DataFrame,
                           labled_theses_df:pd.DataFrame,
                           parties_list:list,
                           plot:bool=False,
                           plot_title:str=''):
    

    # Get unique labels from the dataframe
    labels = pd.unique(labled_theses_df[parties_list].values.ravel()).tolist()

    target_lables_array = labled_theses_df[parties_list].values.ravel()
    predicted_lables_array = predicted_theses_df_mapped[parties_list].values.ravel()

    accuracy    = accuracy_score(target_lables_array, predicted_lables_array)
    precision   = precision_score(target_lables_array, predicted_lables_array, average="macro")
    recall      = recall_score(target_lables_array, predicted_lables_array, average="macro")
    f1          = f1_score(target_lables_array, predicted_lables_array, average="macro")

    if plot:
        # Confusion Matrix berechnen
        cm = confusion_matrix(target_lables_array,
                            predicted_lables_array,
                            labels=labels)

        # Classification Report als einfachen String holen
        report_text = classification_report(target_lables_array,
                                            predicted_lables_array,
                                            labels=labels,
                                            target_names=labels)

        # Plot erstellen
        fig, ax = plt.subplots(figsize=(6, 6))

        # Heatmap zeichnen
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels, ax=ax)
        ax.set_xlabel("Predicted Label")
        ax.set_ylabel("True Label")
        ax.set_title(plot_title)

        # Classification Report als Text im Plot ausgeben
        plt.gcf().text(0.07, 0.15, report_text, fontsize = 10, ha="left", va="center", family="monospace")

        plt.subplots_adjust(bottom=0.4)  # Falls der Text unten abgeschnitten wird

        plt.show()

    return [accuracy, precision, recall, f1]

# %%
import os
import pickle

models_list = ['sentence-transformers/paraphrase-multilingual-mpnet-base-v2', 'mmmaurer/sbert-hashtag-german-politicians-2021', "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"]
model_names_list = ['paraphrase_multilingual_mpnet_base_v2', 'sbert_hashtag_german_politicians_2021', 'paraphrase_multilingual_MiniLM_L12_v2']
text_columns_list = ['These', 'These_no_stopwords', 'These_lemmatized', 'These_unique_words']

lable_list = ["stimme nicht zu", "neutral", "stimme zu"]
parties_list = ['CDU / CSU', 'GRÜNE', 'SPD', 'AfD', 'Die Linke', 'FDP']

folder_path = r'Prediction_Classes_Data\Theses'

# Socres:   [accuracy, precision, recall, f1]
Model_prediction_scores = pd.DataFrame(columns= ['model', 'lable_text_column', 'party_text_column' ,'Manifesto_sorted', 'accuracy', 'precision', 'recall', 'f1'])


for idx, model in enumerate(models_list):
    tokenizer = AutoTokenizer.from_pretrained(model)
    model = AutoModel.from_pretrained(model)

    
    for text_column in text_columns_list:
        lable_text_column = text_column
        party_text_column = text_column
        predicted_theses_dfs_dict, predicted_theses_df = similarity_func(all_party_textes_df,
                                                                         labled_theses_df,
                                                                         lable_text_column,
                                                                         party_text_column, 
                                                                         plot=False) 
                                                                         
        folder_path_file = os.path.join(folder_path,model_names_list[idx], text_column)
        os.makedirs(folder_path_file, exist_ok=True)
        with open(os.path.join(folder_path_file, 'predicted_theses_dfs_dict.pkl'), 'wb') as f:
            pickle.dump(predicted_theses_dfs_dict, f)
        with open(os.path.join(folder_path_file, 'predicted_theses_df.pkl'), 'wb') as f:
            pickle.dump(predicted_theses_df, f)
        #Mapping des predicted theses dfs
        predicted_theses_df_mapped = mapping_similarity_to_class_func(predicted_theses_df, lable_list)
        #Apply Metric to evaluate Predictions
        scores_list = prediction_metric_func(predicted_theses_df_mapped, labled_theses_df, parties_list, plot=True, plot_title=f'{model_names_list[idx]}-{text_column}')
        #Save Metrics in df to compare
        Model_prediction_scores.loc[len(Model_prediction_scores)] = [model_names_list[idx], lable_text_column, party_text_column, 'class prefitted' ]+scores_list
            
with open(os.path.join(folder_path, 'Model_prediction_scores.pkl'), 'wb') as f:
    pickle.dump(Model_prediction_scores, f)
# Out:
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)

# %%
party_text_columns_list = ['Text',  'Text_no_stopwords',  'Text_lemmatized']
lable_text_columns_list = ['These', 'These_no_stopwords', 'These_lemmatized']

folder_path = r'Prediction_Classes_Data\Text'

# Socres:   [accuracy, precision, recall, f1]
Model_prediction_scores = pd.DataFrame(columns= ['model', 'lable_text_column', 'party_text_column' ,'Manifesto_sorted', 'accuracy', 'precision', 'recall', 'f1'])


for idx, model in enumerate(models_list):
    tokenizer = AutoTokenizer.from_pretrained(model)
    model = AutoModel.from_pretrained(model)

    
    for text_idx, text_column in enumerate(lable_text_columns_list):
        lable_text_column = text_column
        party_text_column = party_text_columns_list[text_idx]
        predicted_theses_dfs_dict, predicted_theses_df = similarity_func(all_party_textes_df,
                                                                         labled_theses_df,
                                                                         lable_text_column,
                                                                         party_text_column, 
                                                                         plot=False) 
                                                                         
        folder_path_file = os.path.join(folder_path,model_names_list[idx], text_column)
        os.makedirs(folder_path_file, exist_ok=True)
        with open(os.path.join(folder_path_file, 'predicted_theses_dfs_dict.pkl'), 'wb') as f:
            pickle.dump(predicted_theses_dfs_dict, f)
        with open(os.path.join(folder_path_file, 'predicted_theses_df.pkl'), 'wb') as f:
            pickle.dump(predicted_theses_df, f)
        #Mapping des predicted theses dfs
        predicted_theses_df_mapped = mapping_similarity_to_class_func(predicted_theses_df, lable_list)
        #Apply Metric to evaluate Predictions
        scores_list = prediction_metric_func(predicted_theses_df_mapped, labled_theses_df, parties_list, plot=True, plot_title=f'{model_names_list[idx]}-{text_column}')
        #Save Metrics in df to compare
        Model_prediction_scores.loc[len(Model_prediction_scores)] = [model_names_list[idx], lable_text_column, party_text_column, 'class prefitted' ]+scores_list
            
with open(os.path.join(folder_path, 'Model_prediction_scores.pkl'), 'wb') as f:
    pickle.dump(Model_prediction_scores, f)
# Out:
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# C:\Users\Franziska Rudolf\AppData\Local\Temp\ipykernel_4788\4187463664.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   predicted_theses_df_mapped[numeric_columns] = predicted_theses_df_mapped[numeric_columns].applymap(map_value)
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Franziska Rudolf\Documents\Masterstudium Unterlagen\Text Mining\Textmining_Wahlprogramme\pupu\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
