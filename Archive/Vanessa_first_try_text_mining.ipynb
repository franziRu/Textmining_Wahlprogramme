# %%
#pip install nltk 
#pip install spacy
#pip install requests beautifulsoup4
# pip install textblob
# pip install wordcloud

# %%
import pandas as pd 
from matplotlib import pyplot as plt
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
import spacy
from collections import Counter 

# nltk lemmatizer funktioniert nicht mit deutsch, deshalb nur zum Testen verwendet
from nltk.stem import WordNetLemmatizer

# %%
# Einlesen der Daten 
all_parties_df = pd.read_parquet("C:\\Users\\vanes\\Documents\\DSB Master\\Term 6\\Text Mining\\Textmining_Wahlprogramme\\all_parties_text_combined.parquet")

# %% [markdown]
# ## Spielereien

# %%
# Testen der Stopwordentfernung an einem Beispiel
test_text = all_parties_df.loc[230, "Text"]

# einfache Analyse der Wortanzahlen 
words = word_tokenize(test_text)
word_lengths = [len(w) for w in words]
plt.hist(word_lengths)

# %%
# EInfaches Zählen der Wörter im Text
tokens = word_tokenize(test_text)
lower_tokens = [t.lower() for t in tokens]
bow_simple = Counter(lower_tokens)
print(bow_simple.most_common(10))
# Out:
# [('der', 9), ('.', 6), (',', 5), ('und', 4), ('wir', 4), ('die', 3), ('zum', 3), ('in', 2), ('zweck', 2), ('sexuellen', 2)]

# %%
# Bag of Words test mit entfernen der Stopwords 
tokens = [w for w in word_tokenize(test_text.lower())
                if w.isalpha() ]

no_stops = [t for t in tokens
                    if t not in stopwords.words('german')]
bow = Counter(no_stops) 

print(bow.most_common(10))
# Out:
# [('zweck', 2), ('sexuellen', 2), ('ausbeutung', 2), ('betroffene', 2), ('opfer', 2), ('menschenhandel', 2), ('frauen', 2), ('stärken', 2), ('besser', 2), ('verbreitetste', 1)]

# %%
# Lemmatisieren der Wörter - Test mit NLTK
wordnet_lemmatizer = WordNetLemmatizer()
lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in no_stops]

bow = Counter(lemmatized)
print(bow.most_common(10))
# Out:
# [('zweck', 2), ('sexuellen', 2), ('ausbeutung', 2), ('betroffene', 2), ('opfer', 2), ('menschenhandel', 2), ('frau', 2), ('stärken', 2), ('besser', 2), ('verbreitetste', 1)]

# %%
# Lemmatisieren der Wörter mit Spacy 
nlp = spacy.load("de_core_news_sm")
doc = nlp(test_text)
lemmatized = [token.lemma_ for token in doc]

print(lemmatized)
# Out:
# ['der', 'verbreitetst', 'Form', 'der', 'Menschenhandel', 'in', 'der', 'EU', 'geschiehen', 'zu', 'Zweck', 'der', 'sexuell', 'Ausbeutung', '--', 'betroffener', 'werden', 'zwingen', '--', 'unter', 'menschenunwürdig', 'Bedingung', 'in', 'der', 'Prostitution', 'zu', 'arbeiten', '--', 'der', 'Opfer', 'von', 'Menschenhandel', 'zu', 'Zweck', 'der', 'sexuell', 'Ausbeutung', 'sein', 'überwiegend', 'Frau', 'und', 'Mädchen', '--', 'wir', 'wollen', 'der', 'international', 'Zusammenarbeit', 'bei', 'der', 'Prävention', '--', 'Strafverfolgung', 'und', 'zu', 'Schutz', 'der', 'betroffener', 'entlang', 'der', 'bereits', 'bestehend', 'Vereinbarung', 'stärken', '--', 'um', 'Frau', 'gut', 'vor', 'Menschenhandel', 'und', 'vor', 'Gewalt', 'zu', 'schützen', '--', 'wollen', 'wir', 'ihr', 'Recht', 'stärken', '--', 'dieser', 'tun', 'wir', '--', 'indem', 'wir', 'sich', 'bei', 'der', 'anstehend', 'Überarbeitung', 'der', 'EU-Opferschutz-Richtlinie', 'dafür', 'stark', 'machen', '--', 'dass', 'aller', 'Opfer', 'von', 'Straftat', 'gut', 'schützen', 'werden', 'und', 'betroffener', 'ein', 'eigenständig', 'Bleiberecht', 'erhalten', '--']

# %% [markdown]
# ## Main

# %%
# Entfernen der Stopwords und Satzzeichen, Zahlen sollen erhalten bleiben, da potentiell weiterer Nutzen
def remove_stopwords(text): 

    tokens = [w for w in word_tokenize(text.lower())
                if w.isalnum() ]

    no_stops = [t for t in tokens
                    if t not in stopwords.words('german')]
    return " ".join(no_stops)

all_parties_df["Text_no_stopwords"] = all_parties_df["Text"].apply(remove_stopwords)

# %%
# Lemmatisieren der Texte mit Spacy
def lemmatize_words(text): 
    doc = nlp(text)
    lemmatized = [token.lemma_ for token in doc]
    return " ".join(lemmatized)

nlp = spacy.load("de_core_news_sm")
all_parties_df["Text_lemmatized"] = all_parties_df["Text_no_stopwords"].apply(lemmatize_words)

# %%
all_parties_df
# Out:
#      Party                                            Chapter  \
# 0      spd                            Worauf es jetzt ankommt
# 1      spd               Ein neuer Aufschwung für Deutschland
# 2      spd  1. Wir kämpfen für neues Wachstum und sichere ...
# 3      spd  1. Wir kämpfen für neues Wachstum und sichere ...
# 4      spd  1. Wir kämpfen für neues Wachstum und sichere ...
# ..     ...                                                ...
# 547  linke   18. Inklusion und Teilhabe – selbstverständlich!
# 548  linke  19. Medien und Kultur für eine plurale Gesells...
# 549  linke  19. Medien und Kultur für eine plurale Gesells...
# 550  linke  19. Medien und Kultur für eine plurale Gesells...
# 551  linke  19. Medien und Kultur für eine plurale Gesells...
#
#                                                  These  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    Wir wollen Energiepreise senken und zentrale E...
# 4    Wir wollen, dass Unternehmen die besten Rahmen...
# ..                                                 ...
# 547                                               None
# 548                                               None
# 549        Kultur – vielfältig und für alle zugänglich
# 550                               Sport ist kein Luxus
# 551  Verbraucher*innen stärken. Schluss mit den Sch...
#
#                                                   Text  \
# 0    Am 23. Februar findet die vorgezogene Bundesta...
# 1    Viele Menschen machen sich derzeit Sorgen um d...
# 2    Dies ist das erste, aber sicher nicht das letz...
# 3    Wir brauchen bezahlbare Energie, sonst geht un...
# 4    Wir können etwas tun für unsere Unternehmen un...
# ..                                                 ...
# 547  Nach unserem Verständnis ist Inklusion der Geg...
# 548  Für demokratische Aushandlung und Meinungsbild...
# 549  Der Zugang zu Kultur soll nicht vom Geldbeutel...
# 550  Sport ist für alle da. Dafür müssen die Zugang...
# 551  Die Konzerne nutzen ihre Macht gegenüber Verbr...
#
#                                      Text_no_stopwords  \
# 0    februar findet vorgezogene bundestagswahl stat...
# 1    viele menschen derzeit sorgen wirtschaft land ...
# 2    erste sicher letzte mal wörter kämpfen verwend...
# 3    brauchen bezahlbare energie geht unternehmen d...
# 4    tun unternehmen wirtschaftsstandort schaffen d...
# ..                                                 ...
# 547  verständnis inklusion gegenentwurf sozialer sp...
# 548  demokratische aushandlung meinungsbildung brau...
# 549  zugang kultur geldbeutel abhängen kunst kultur...
# 550  sport dafür müssen zugangsbedingungen verbesse...
# 551  konzerne nutzen macht gegenüber verbraucher in...
#
#                                        Text_lemmatized
# 0    Februar finden vorgezogen Bundestagswahl statt...
# 1    vieler Mensch derzeit sorgen Wirtschaft Land s...
# 2    erster sicher letzter Mal wört kämpfen verwend...
# 3    brauchen bezahlbar Energie gehen Unternehmen D...
# 4    tun unternehmen wirtschaftsstandort schaffen d...
# ..                                                 ...
# 547  Verständnis Inklusion Gegenentwurf sozial Spal...
# 548  demokratisch Aushandlung Meinungsbildung brauc...
# 549  Zugang Kultur Geldbeutel abhäng Kunst Kultur z...
# 550  Sport dafür müssen zugangsbedingungen verbesse...
# 551  Konzern nutzen machen gegenüber Verbraucher in...
#
# [552 rows x 6 columns]

# %%
file_name = 'all_parties_text_combined_prep.parquet' 
all_parties_df.to_parquet(file_name, index=False)
